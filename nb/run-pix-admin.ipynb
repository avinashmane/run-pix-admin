# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['', 'import pandas as pd', 'globals()', 'globals()'],
#  '_oh': {2: {...}},
#  '_dh': [PosixPath('/home/avinashmane/run-pix-admin/nb'),
#   PosixPath('/home/avinashmane/run-pix-admin/nb'),
#   PosixPath('/home/avinashmane/run-pix-admin/nb')],
#  'In': ['', 'import pandas as pd', 'globals()', 'globals()'],
#  'Out': {2: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x7fdb67bfcf40>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x7fdb67c0c8b0>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x7fdb67c0c8b0>,
# ...
